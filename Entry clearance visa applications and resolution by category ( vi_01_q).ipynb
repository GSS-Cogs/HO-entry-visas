# %% [markdown]
# Table vi_01_q: Entry clearance visa applications and resolution by category

# %%
from gssutils import *

if is_interactive():
    scraper = Scraper('https://www.gov.uk/government/statistics/immigration-statistics-october-to-december-2017-data-tables')
    sheet = scraper.distribution(
        title='Entry clearance visas granted outside the UK data tables immigration statistics October to December 2017 volume 1'
    ).as_pandas(sheet_name='vi_01_q')
sheet
# Out:
#                                                      0   \
# 0     Table vi_01_q: Entry clearance visa applicatio...
# 1                                      Back to contents
# 2
# 3                                               Quarter
# 4                                               2005 Q1
# 5                                               2005 Q1
# 6                                               2005 Q1
# 7                                               2005 Q1
# 8                                               2005 Q1
# 9                                               2005 Q1
# 10                                              2005 Q1
# 11                                              2005 Q1
# 12                                              2005 Q1
# 13                                              2005 Q1
# 14                                              2005 Q1
# 15                                              2005 Q1
# 16                                              2005 Q1
# 17                                              2005 Q1
# 18                                              2005 Q1
# 19                                              2005 Q1
# 20                                              2005 Q1
# 21                                              2005 Q1
# 22                                              2005 Q1
# 23                                              2005 Q1
# 24                                              2005 Q1
# 25                                              2005 Q1
# 26                                              2005 Q1
# 27                                              2005 Q1
# 28                                              2005 Q1
# 29                                              2005 Q1
# ...                                                 ...
# 4551                                            2017 Q4
# 4552                                            2017 Q4
# 4553                                            2017 Q4
# 4554                                            2017 Q4
# 4555                                            2017 Q4
# 4556                                            2017 Q4
# 4557                                            2017 Q4
# 4558                                            2017 Q4
# 4559                                            2017 Q4
# 4560                                            2017 Q4
# 4561                                            2017 Q4
# 4562                                            2017 Q4
# 4563                                            2017 Q4
# 4564                                            2017 Q4
# 4565                                            2017 Q4
# 4566                                            2017 Q4
# 4567                                            2017 Q4
# 4568                                            2017 Q4
# 4569                                            2017 Q4
# 4570                                            2017 Q4
# 4571                                            2017 Q4
# 4572                                            2017 Q4
# 4573                                            2017 Q4
# 4574                                            2017 Q4
# 4575                                            2017 Q4
# 4576                                            2017 Q4
# 4577                                            2017 Q4
# 4578                                            2017 Q4
# 4579                                            2017 Q4
# 4580
#
#                                        1                             2   \
# 0
# 1
# 2
# 3                                    Type                Broad category
# 4                                  *Total                        *Total
# 5     *Total (excl. Visitors and transit)                        *Total
# 6                                    Work                        *Total
# 7                                   Study                        *Total
# 8                                   Study                        *Total
# 9                                  Family                        *Total
# 10           Dep. joining or accompanying                        *Total
# 11                                  Other                        *Total
# 12                                   Work   Tier 1 & pre-PBS equivalent
# 13                                   Work   Tier 1 & pre-PBS equivalent
# 14                                   Work   Tier 2 & pre-PBS equivalent
# 15                                   Work   Tier 2 & pre-PBS equivalent
# 16                                   Work   Tier 5 & pre-PBS equivalent
# 17                                   Work   Tier 5 & pre-PBS equivalent
# 18                                   Work                       Non-PBS
# 19                                   Work                       Non-PBS
# 20                                   Work                         Other
# 21                                  Study   Tier 4 & pre-PBS equivalent
# 22                                  Study   Tier 4 & pre-PBS equivalent
# 23                                   Work   Tier 1 & pre-PBS equivalent
# 24                                   Work   Tier 1 & pre-PBS equivalent
# 25                                   Work   Tier 1 & pre-PBS equivalent
# 26                                   Work   Tier 1 & pre-PBS equivalent
# 27                                   Work   Tier 1 & pre-PBS equivalent
# 28                                   Work   Tier 1 & pre-PBS equivalent
# 29                                   Work   Tier 1 & pre-PBS equivalent
# ...                                   ...                           ...
# 4551                                 Work   Tier 5 & pre-PBS equivalent
# 4552                                 Work                       Non-PBS
# 4553                                 Work                       Non-PBS
# 4554                                 Work                       Non-PBS
# 4555                                 Work                       Non-PBS
# 4556                                 Work                         Other
# 4557                                Study   Tier 4 & pre-PBS equivalent
# 4558                                Study   Tier 4 & pre-PBS equivalent
# 4559                                Study   Tier 4 & pre-PBS equivalent
# 4560                                Study   Tier 4 & pre-PBS equivalent
# 4561                                Study   Tier 4 & pre-PBS equivalent
# 4562                                Study   Tier 4 & pre-PBS equivalent
# 4563                                Study                       Non-PBS
# 4564                               Family                        Family
# 4565                               Family                        Family
# 4566                               Family                        Family
# 4567                               Family                        Family
# 4568                               Family                        Family
# 4569                               Family                        Family
# 4570         Dep. joining or accompanying  Dep. joining or accompanying
# 4571         Dep. joining or accompanying  Dep. joining or accompanying
# 4572         Dep. joining or accompanying  Dep. joining or accompanying
# 4573                                Other         Other temporary visas
# 4574                                Other         Other temporary visas
# 4575                                Other         Other temporary visas
# 4576                                Other         Other temporary visas
# 4577                                Other         Other temporary visas
# 4578                                Other        Other settlement visas
# 4579                                Other        Other settlement visas
# 4580
#
#                   3                                               4   \
# 0
# 1
# 2
# 3     Applicant type                                        Category
# 4             *Total                                          *Total
# 5             *Total         *Total (excluding visitors and transit)
# 6             *Total                                          *Total
# 7             *Total             *Total (including Short-term study)
# 8             *Total             *Total (excluding Short-term study)
# 9             *Total                                          *Total
# 10            *Total                                          *Total
# 11            *Total                                          *Total
# 12    Main applicant                                          *Total
# 13         Dependant                                          *Total
# 14    Main applicant                                          *Total
# 15         Dependant                                          *Total
# 16    Main applicant                                          *Total
# 17         Dependant                                          *Total
# 18    Main applicant                                          *Total
# 19         Dependant                                          *Total
# 20    Main applicant                                          *Total
# 21    Main applicant                                          *Total
# 22         Dependant                                          *Total
# 23    Main applicant                                Tier 1 - General
# 24    Main applicant                              Tier 1 - Investors
# 25    Main applicant                          Tier 1 - Entrepreneurs
# 26    Main applicant                 Tier 1 - Graduate entrepreneurs
# 27    Main applicant                             Tier 1 - Post Study
# 28    Main applicant                     Tier 1 - Exceptional Talent
# 29    Main applicant                                  Tier 1 - Other
# ...              ...                                             ...
# 4551       Dependant                                Tier 5 Dependant
# 4552  Main applicant          Domestic workers in Private Households
# 4553  Main applicant                                     UK Ancestry
# 4554  Main applicant          Other permit free employment - Non-PBS
# 4555       Dependant          Domestic workers in Private Households
# 4556  Main applicant      Other permit free employment not allocated
# 4557  Main applicant                        Tier 4 - General student
# 4558  Main applicant                          Tier 4 - Child student
# 4559  Main applicant                                        Students
# 4560  Main applicant                   Trainees - doctors & dentists
# 4561       Dependant                        Tier 4 - General student
# 4562       Dependant                                        Students
# 4563  Main applicant  Short-term study (previously Student Visitors)
# 4564             All                                 Family: Partner
# 4565             All                Family: Partner (for settlement)
# 4566             All                                   Family: Child
# 4567             All                  Family: Child (for settlement)
# 4568             All                                   Family: Other
# 4569             All                  Family: Other (for settlement)
# 4570       Dependant                Joining or accompanying: Partner
# 4571       Dependant                  Joining or accompanying: Child
# 4572       Dependant                  Joining or accompanying: Other
# 4573             All                              EEA family permits
# 4574  Main applicant                                        Visitors
# 4575       Dependant                                        Visitors
# 4576             All                                         Transit
# 4577             All                                 Other temporary
# 4578  Main applicant    Certificate of entitlement to right of abode
# 4579             All             Other settlement (indefinite leave)
# 4580
#
#                 5         6        7         8        9           10  \
# 0
# 1
# 2
# 3     Applications  Resolved  Granted         %  Refused           %
# 4           549934    544208   428907  0.788131   108812    0.199946
# 5           158424    157409   121258  0.770337    33704    0.214117
# 6            72805     70631    60550  0.857272     8745    0.123812
# 7            47737     49921    29018  0.581278    20236     0.40536
# 8            44870     47049    26335  0.559736    20068    0.426534
# 9            19917     19415    15943  0.821169     3258    0.167808
# 10            8209      8052     6850   0.85072     1105    0.137233
# 11          401266    396189   316546  0.798977    75468    0.190485
# 12            1814      3218     1430  0.444375     1294    0.402113
# 13              59         0        0         0        0           0
# 14           17562     17521    15909  0.907996     1523   0.0869243
# 15           12333     11861    10920  0.920664      893   0.0752888
# 16           27148     25519    20948  0.820879     4059    0.159058
# 17               z         z        z         z        z           z
# 18            5937      5757     5169  0.897863      469    0.081466
# 19              41        36       22  0.611111       14    0.388889
# 20            7911      6719     6152  0.915612      493    0.073374
# 21           40690     42893    23108  0.538736    19171    0.446949
# 22            4180      4156     3227  0.776468      897    0.215833
# 23               z         z        z         z        z           z
# 24               z         z        z         z        z           z
# 25               z         z        z         z        z           z
# 26               z         z        z         z        z           z
# 27               z         z        z         z        z           z
# 28               z         z        z         z        z           z
# 29               z         z        z         z        z           z
# ...            ...       ...      ...       ...      ...         ...
# 4551           567       548      478  0.872263       70    0.127737
# 4552          4574      4583     4119  0.898756      445    0.097098
# 4553           856       794      759  0.955919       30   0.0377834
# 4554           239       239      182  0.761506       56     0.23431
# 4555            32        12        3      0.25        6         0.5
# 4556           120       124      124         1        0           0
# 4557         16112     15942    14572  0.914063     1255   0.0787229
# 4558          1022      1027      939  0.914314       82   0.0798442
# 4559             2         3        1  0.333333        1    0.333333
# 4560             z         z        z         z        z           z
# 4561          2761      2732     2376  0.869693      351    0.128477
# 4562             1         2        z         z        2           1
# 4563         16916     15644    13571  0.867489     2029    0.129698
# 4564          9523     14328    10605  0.740159     3653    0.254955
# 4565            41        83       78  0.939759        5    0.060241
# 4566            85        14        5  0.357143        9    0.642857
# 4567          1767      1577      703  0.445783      861    0.545973
# 4568          1991      2115     1513  0.715366      587    0.277541
# 4569            40       145       47  0.324138       97    0.668966
# 4570           539       589      525  0.891341       60    0.101868
# 4571          1012      2370     1722  0.726582      631    0.266245
# 4572            12        40       11     0.275       29       0.725
# 4573         10014     12430     8435    0.6786     3434    0.276267
# 4574        417610    421871   359120  0.851255    61777    0.146436
# 4575         34005     34154    29480  0.863149     4569    0.133776
# 4576          4309      4346     3914  0.900598      367   0.0844455
# 4577          4541      4455     4318  0.969248       34  0.00763187
# 4578           353       399      342  0.857143       48    0.120301
# 4579           253       476      386  0.810924       81    0.170168
# 4580
#
#              11      12
# 0
# 1
# 2
# 3     Withdrawn  Lapsed
# 4          4888    1601
# 5          2111     336
# 6          1220     116
# 7           527     140
# 8           517     129
# 9           181      33
# 10           79      18
# 11         2881    1294
# 12          490       4
# 13            0       0
# 14           73      16
# 15           35      13
# 16          481      31
# 17            z       z
# 18           96      23
# 19            0       0
# 20           45      29
# 21          493     121
# 22           24       8
# 23            z       z
# 24            z       z
# 25            z       z
# 26            z       z
# 27            z       z
# 28            z       z
# 29            z       z
# ...         ...     ...
# 4551          0       0
# 4552         18       1
# 4553          5       0
# 4554          1       0
# 4555          3       0
# 4556          0       0
# 4557        115       0
# 4558          6       0
# 4559          1       z
# 4560          z       z
# 4561          5       0
# 4562          z       z
# 4563         44       0
# 4564         68       2
# 4565          0       0
# 4566          0       0
# 4567         13       0
# 4568         15       0
# 4569          1       0
# 4570          4       0
# 4571         17       0
# 4572          0       0
# 4573        561       0
# 4574        970       4
# 4575        103       2
# 4576         65       0
# 4577        103       0
# 4578          9       0
# 4579          9       0
# 4580
#
# [4581 rows x 13 columns]

# %%
sheet.rename(columns=sheet.iloc[3], inplace=True)
sheet.drop([0,1,2,3], inplace=True)
sheet.drop(sheet.index[sheet['Quarter'] == ''], inplace=True)
sheet
# Out:
#       Quarter                                 Type  \
# 4     2005 Q1                               *Total
# 5     2005 Q1  *Total (excl. Visitors and transit)
# 6     2005 Q1                                 Work
# 7     2005 Q1                                Study
# 8     2005 Q1                                Study
# 9     2005 Q1                               Family
# 10    2005 Q1         Dep. joining or accompanying
# 11    2005 Q1                                Other
# 12    2005 Q1                                 Work
# 13    2005 Q1                                 Work
# 14    2005 Q1                                 Work
# 15    2005 Q1                                 Work
# 16    2005 Q1                                 Work
# 17    2005 Q1                                 Work
# 18    2005 Q1                                 Work
# 19    2005 Q1                                 Work
# 20    2005 Q1                                 Work
# 21    2005 Q1                                Study
# 22    2005 Q1                                Study
# 23    2005 Q1                                 Work
# 24    2005 Q1                                 Work
# 25    2005 Q1                                 Work
# 26    2005 Q1                                 Work
# 27    2005 Q1                                 Work
# 28    2005 Q1                                 Work
# 29    2005 Q1                                 Work
# 30    2005 Q1                                 Work
# 31    2005 Q1                                 Work
# 32    2005 Q1                                 Work
# 33    2005 Q1                                 Work
# ...       ...                                  ...
# 4550  2017 Q4                                 Work
# 4551  2017 Q4                                 Work
# 4552  2017 Q4                                 Work
# 4553  2017 Q4                                 Work
# 4554  2017 Q4                                 Work
# 4555  2017 Q4                                 Work
# 4556  2017 Q4                                 Work
# 4557  2017 Q4                                Study
# 4558  2017 Q4                                Study
# 4559  2017 Q4                                Study
# 4560  2017 Q4                                Study
# 4561  2017 Q4                                Study
# 4562  2017 Q4                                Study
# 4563  2017 Q4                                Study
# 4564  2017 Q4                               Family
# 4565  2017 Q4                               Family
# 4566  2017 Q4                               Family
# 4567  2017 Q4                               Family
# 4568  2017 Q4                               Family
# 4569  2017 Q4                               Family
# 4570  2017 Q4         Dep. joining or accompanying
# 4571  2017 Q4         Dep. joining or accompanying
# 4572  2017 Q4         Dep. joining or accompanying
# 4573  2017 Q4                                Other
# 4574  2017 Q4                                Other
# 4575  2017 Q4                                Other
# 4576  2017 Q4                                Other
# 4577  2017 Q4                                Other
# 4578  2017 Q4                                Other
# 4579  2017 Q4                                Other
#
#                     Broad category  Applicant type  \
# 4                           *Total          *Total
# 5                           *Total          *Total
# 6                           *Total          *Total
# 7                           *Total          *Total
# 8                           *Total          *Total
# 9                           *Total          *Total
# 10                          *Total          *Total
# 11                          *Total          *Total
# 12     Tier 1 & pre-PBS equivalent  Main applicant
# 13     Tier 1 & pre-PBS equivalent       Dependant
# 14     Tier 2 & pre-PBS equivalent  Main applicant
# 15     Tier 2 & pre-PBS equivalent       Dependant
# 16     Tier 5 & pre-PBS equivalent  Main applicant
# 17     Tier 5 & pre-PBS equivalent       Dependant
# 18                         Non-PBS  Main applicant
# 19                         Non-PBS       Dependant
# 20                           Other  Main applicant
# 21     Tier 4 & pre-PBS equivalent  Main applicant
# 22     Tier 4 & pre-PBS equivalent       Dependant
# 23     Tier 1 & pre-PBS equivalent  Main applicant
# 24     Tier 1 & pre-PBS equivalent  Main applicant
# 25     Tier 1 & pre-PBS equivalent  Main applicant
# 26     Tier 1 & pre-PBS equivalent  Main applicant
# 27     Tier 1 & pre-PBS equivalent  Main applicant
# 28     Tier 1 & pre-PBS equivalent  Main applicant
# 29     Tier 1 & pre-PBS equivalent  Main applicant
# 30     Tier 1 & pre-PBS equivalent  Main applicant
# 31     Tier 1 & pre-PBS equivalent  Main applicant
# 32     Tier 1 & pre-PBS equivalent       Dependant
# 33     Tier 1 & pre-PBS equivalent       Dependant
# ...                            ...             ...
# 4550   Tier 5 & pre-PBS equivalent  Main applicant
# 4551   Tier 5 & pre-PBS equivalent       Dependant
# 4552                       Non-PBS  Main applicant
# 4553                       Non-PBS  Main applicant
# 4554                       Non-PBS  Main applicant
# 4555                       Non-PBS       Dependant
# 4556                         Other  Main applicant
# 4557   Tier 4 & pre-PBS equivalent  Main applicant
# 4558   Tier 4 & pre-PBS equivalent  Main applicant
# 4559   Tier 4 & pre-PBS equivalent  Main applicant
# 4560   Tier 4 & pre-PBS equivalent  Main applicant
# 4561   Tier 4 & pre-PBS equivalent       Dependant
# 4562   Tier 4 & pre-PBS equivalent       Dependant
# 4563                       Non-PBS  Main applicant
# 4564                        Family             All
# 4565                        Family             All
# 4566                        Family             All
# 4567                        Family             All
# 4568                        Family             All
# 4569                        Family             All
# 4570  Dep. joining or accompanying       Dependant
# 4571  Dep. joining or accompanying       Dependant
# 4572  Dep. joining or accompanying       Dependant
# 4573         Other temporary visas             All
# 4574         Other temporary visas  Main applicant
# 4575         Other temporary visas       Dependant
# 4576         Other temporary visas             All
# 4577         Other temporary visas             All
# 4578        Other settlement visas  Main applicant
# 4579        Other settlement visas             All
#
#                                             Category Applications Resolved  \
# 4                                             *Total       549934   544208
# 5            *Total (excluding visitors and transit)       158424   157409
# 6                                             *Total        72805    70631
# 7                *Total (including Short-term study)        47737    49921
# 8                *Total (excluding Short-term study)        44870    47049
# 9                                             *Total        19917    19415
# 10                                            *Total         8209     8052
# 11                                            *Total       401266   396189
# 12                                            *Total         1814     3218
# 13                                            *Total           59        0
# 14                                            *Total        17562    17521
# 15                                            *Total        12333    11861
# 16                                            *Total        27148    25519
# 17                                            *Total            z        z
# 18                                            *Total         5937     5757
# 19                                            *Total           41       36
# 20                                            *Total         7911     6719
# 21                                            *Total        40690    42893
# 22                                            *Total         4180     4156
# 23                                  Tier 1 - General            z        z
# 24                                Tier 1 - Investors            z        z
# 25                            Tier 1 - Entrepreneurs            z        z
# 26                   Tier 1 - Graduate entrepreneurs            z        z
# 27                               Tier 1 - Post Study            z        z
# 28                       Tier 1 - Exceptional Talent            z        z
# 29                                    Tier 1 - Other            z        z
# 30                    International Graduates Scheme            z        z
# 31         Other permit free employment - High value         1814     3218
# 32                                  Tier 1 - General            z        z
# 33                                Tier 1 - Investors            z        z
# ...                                              ...          ...      ...
# 4550                    Other permit free employment            z        z
# 4551                                Tier 5 Dependant          567      548
# 4552          Domestic workers in Private Households         4574     4583
# 4553                                     UK Ancestry          856      794
# 4554          Other permit free employment - Non-PBS          239      239
# 4555          Domestic workers in Private Households           32       12
# 4556      Other permit free employment not allocated          120      124
# 4557                        Tier 4 - General student        16112    15942
# 4558                          Tier 4 - Child student         1022     1027
# 4559                                        Students            2        3
# 4560                   Trainees - doctors & dentists            z        z
# 4561                        Tier 4 - General student         2761     2732
# 4562                                        Students            1        2
# 4563  Short-term study (previously Student Visitors)        16916    15644
# 4564                                 Family: Partner         9523    14328
# 4565                Family: Partner (for settlement)           41       83
# 4566                                   Family: Child           85       14
# 4567                  Family: Child (for settlement)         1767     1577
# 4568                                   Family: Other         1991     2115
# 4569                  Family: Other (for settlement)           40      145
# 4570                Joining or accompanying: Partner          539      589
# 4571                  Joining or accompanying: Child         1012     2370
# 4572                  Joining or accompanying: Other           12       40
# 4573                              EEA family permits        10014    12430
# 4574                                        Visitors       417610   421871
# 4575                                        Visitors        34005    34154
# 4576                                         Transit         4309     4346
# 4577                                 Other temporary         4541     4455
# 4578    Certificate of entitlement to right of abode          353      399
# 4579             Other settlement (indefinite leave)          253      476
#
#      Granted         % Refused           % Withdrawn Lapsed
# 4     428907  0.788131  108812    0.199946      4888   1601
# 5     121258  0.770337   33704    0.214117      2111    336
# 6      60550  0.857272    8745    0.123812      1220    116
# 7      29018  0.581278   20236     0.40536       527    140
# 8      26335  0.559736   20068    0.426534       517    129
# 9      15943  0.821169    3258    0.167808       181     33
# 10      6850   0.85072    1105    0.137233        79     18
# 11    316546  0.798977   75468    0.190485      2881   1294
# 12      1430  0.444375    1294    0.402113       490      4
# 13         0         0       0           0         0      0
# 14     15909  0.907996    1523   0.0869243        73     16
# 15     10920  0.920664     893   0.0752888        35     13
# 16     20948  0.820879    4059    0.159058       481     31
# 17         z         z       z           z         z      z
# 18      5169  0.897863     469    0.081466        96     23
# 19        22  0.611111      14    0.388889         0      0
# 20      6152  0.915612     493    0.073374        45     29
# 21     23108  0.538736   19171    0.446949       493    121
# 22      3227  0.776468     897    0.215833        24      8
# 23         z         z       z           z         z      z
# 24         z         z       z           z         z      z
# 25         z         z       z           z         z      z
# 26         z         z       z           z         z      z
# 27         z         z       z           z         z      z
# 28         z         z       z           z         z      z
# 29         z         z       z           z         z      z
# 30         z         z       z           z         z      z
# 31      1430  0.444375    1294    0.402113       490      4
# 32         z         z       z           z         z      z
# 33         z         z       z           z         z      z
# ...      ...       ...     ...         ...       ...    ...
# 4550       z         z       z           z         z      z
# 4551     478  0.872263      70    0.127737         0      0
# 4552    4119  0.898756     445    0.097098        18      1
# 4553     759  0.955919      30   0.0377834         5      0
# 4554     182  0.761506      56     0.23431         1      0
# 4555       3      0.25       6         0.5         3      0
# 4556     124         1       0           0         0      0
# 4557   14572  0.914063    1255   0.0787229       115      0
# 4558     939  0.914314      82   0.0798442         6      0
# 4559       1  0.333333       1    0.333333         1      z
# 4560       z         z       z           z         z      z
# 4561    2376  0.869693     351    0.128477         5      0
# 4562       z         z       2           1         z      z
# 4563   13571  0.867489    2029    0.129698        44      0
# 4564   10605  0.740159    3653    0.254955        68      2
# 4565      78  0.939759       5    0.060241         0      0
# 4566       5  0.357143       9    0.642857         0      0
# 4567     703  0.445783     861    0.545973        13      0
# 4568    1513  0.715366     587    0.277541        15      0
# 4569      47  0.324138      97    0.668966         1      0
# 4570     525  0.891341      60    0.101868         4      0
# 4571    1722  0.726582     631    0.266245        17      0
# 4572      11     0.275      29       0.725         0      0
# 4573    8435    0.6786    3434    0.276267       561      0
# 4574  359120  0.851255   61777    0.146436       970      4
# 4575   29480  0.863149    4569    0.133776       103      2
# 4576    3914  0.900598     367   0.0844455        65      0
# 4577    4318  0.969248      34  0.00763187       103      0
# 4578     342  0.857143      48    0.120301         9      0
# 4579     386  0.810924      81    0.170168         9      0
#
# [4576 rows x 13 columns]

# %% [markdown]
# Let's consider the columns up to 'Category' to be the main dimensions, ignore the derived % calculations and collapse down the various types of applications under a 'Resolution' column:

# %%
tidy = pd.wide_to_long(
    sheet.drop(columns=['%']).rename(columns={'Applications': 'Applications All',
                    'Resolved': 'Applications Resolved',
                    'Granted': 'Applications Granted',
                    'Refused': 'Applications Refused',
                    'Withdrawn': 'Applications Withdrawn',
                    'Lapsed': 'Applications Lapsed'}),
                stubnames='Applications',
                i=['Quarter', 'Type', 'Broad category', 'Applicant type', 'Category'],
                sep=' ',
                suffix='.*',
                j='Resolution').reset_index()
tidy
# Out:
#        Quarter                                 Type          Broad category  \
# 0      2005 Q1                               *Total                  *Total
# 1      2005 Q1                               *Total                  *Total
# 2      2005 Q1                               *Total                  *Total
# 3      2005 Q1                               *Total                  *Total
# 4      2005 Q1                               *Total                  *Total
# 5      2005 Q1                               *Total                  *Total
# 6      2005 Q1  *Total (excl. Visitors and transit)                  *Total
# 7      2005 Q1  *Total (excl. Visitors and transit)                  *Total
# 8      2005 Q1  *Total (excl. Visitors and transit)                  *Total
# 9      2005 Q1  *Total (excl. Visitors and transit)                  *Total
# 10     2005 Q1  *Total (excl. Visitors and transit)                  *Total
# 11     2005 Q1  *Total (excl. Visitors and transit)                  *Total
# 12     2005 Q1                                 Work                  *Total
# 13     2005 Q1                                 Work                  *Total
# 14     2005 Q1                                 Work                  *Total
# 15     2005 Q1                                 Work                  *Total
# 16     2005 Q1                                 Work                  *Total
# 17     2005 Q1                                 Work                  *Total
# 18     2005 Q1                                Study                  *Total
# 19     2005 Q1                                Study                  *Total
# 20     2005 Q1                                Study                  *Total
# 21     2005 Q1                                Study                  *Total
# 22     2005 Q1                                Study                  *Total
# 23     2005 Q1                                Study                  *Total
# 24     2005 Q1                                Study                  *Total
# 25     2005 Q1                                Study                  *Total
# 26     2005 Q1                                Study                  *Total
# 27     2005 Q1                                Study                  *Total
# 28     2005 Q1                                Study                  *Total
# 29     2005 Q1                                Study                  *Total
# ...        ...                                  ...                     ...
# 27426  2017 Q4                                Other   Other temporary visas
# 27427  2017 Q4                                Other   Other temporary visas
# 27428  2017 Q4                                Other   Other temporary visas
# 27429  2017 Q4                                Other   Other temporary visas
# 27430  2017 Q4                                Other   Other temporary visas
# 27431  2017 Q4                                Other   Other temporary visas
# 27432  2017 Q4                                Other   Other temporary visas
# 27433  2017 Q4                                Other   Other temporary visas
# 27434  2017 Q4                                Other   Other temporary visas
# 27435  2017 Q4                                Other   Other temporary visas
# 27436  2017 Q4                                Other   Other temporary visas
# 27437  2017 Q4                                Other   Other temporary visas
# 27438  2017 Q4                                Other   Other temporary visas
# 27439  2017 Q4                                Other   Other temporary visas
# 27440  2017 Q4                                Other   Other temporary visas
# 27441  2017 Q4                                Other   Other temporary visas
# 27442  2017 Q4                                Other   Other temporary visas
# 27443  2017 Q4                                Other   Other temporary visas
# 27444  2017 Q4                                Other  Other settlement visas
# 27445  2017 Q4                                Other  Other settlement visas
# 27446  2017 Q4                                Other  Other settlement visas
# 27447  2017 Q4                                Other  Other settlement visas
# 27448  2017 Q4                                Other  Other settlement visas
# 27449  2017 Q4                                Other  Other settlement visas
# 27450  2017 Q4                                Other  Other settlement visas
# 27451  2017 Q4                                Other  Other settlement visas
# 27452  2017 Q4                                Other  Other settlement visas
# 27453  2017 Q4                                Other  Other settlement visas
# 27454  2017 Q4                                Other  Other settlement visas
# 27455  2017 Q4                                Other  Other settlement visas
#
#        Applicant type                                      Category  \
# 0              *Total                                        *Total
# 1              *Total                                        *Total
# 2              *Total                                        *Total
# 3              *Total                                        *Total
# 4              *Total                                        *Total
# 5              *Total                                        *Total
# 6              *Total       *Total (excluding visitors and transit)
# 7              *Total       *Total (excluding visitors and transit)
# 8              *Total       *Total (excluding visitors and transit)
# 9              *Total       *Total (excluding visitors and transit)
# 10             *Total       *Total (excluding visitors and transit)
# 11             *Total       *Total (excluding visitors and transit)
# 12             *Total                                        *Total
# 13             *Total                                        *Total
# 14             *Total                                        *Total
# 15             *Total                                        *Total
# 16             *Total                                        *Total
# 17             *Total                                        *Total
# 18             *Total           *Total (including Short-term study)
# 19             *Total           *Total (including Short-term study)
# 20             *Total           *Total (including Short-term study)
# 21             *Total           *Total (including Short-term study)
# 22             *Total           *Total (including Short-term study)
# 23             *Total           *Total (including Short-term study)
# 24             *Total           *Total (excluding Short-term study)
# 25             *Total           *Total (excluding Short-term study)
# 26             *Total           *Total (excluding Short-term study)
# 27             *Total           *Total (excluding Short-term study)
# 28             *Total           *Total (excluding Short-term study)
# 29             *Total           *Total (excluding Short-term study)
# ...               ...                                           ...
# 27426       Dependant                                      Visitors
# 27427       Dependant                                      Visitors
# 27428       Dependant                                      Visitors
# 27429       Dependant                                      Visitors
# 27430       Dependant                                      Visitors
# 27431       Dependant                                      Visitors
# 27432             All                                       Transit
# 27433             All                                       Transit
# 27434             All                                       Transit
# 27435             All                                       Transit
# 27436             All                                       Transit
# 27437             All                                       Transit
# 27438             All                               Other temporary
# 27439             All                               Other temporary
# 27440             All                               Other temporary
# 27441             All                               Other temporary
# 27442             All                               Other temporary
# 27443             All                               Other temporary
# 27444  Main applicant  Certificate of entitlement to right of abode
# 27445  Main applicant  Certificate of entitlement to right of abode
# 27446  Main applicant  Certificate of entitlement to right of abode
# 27447  Main applicant  Certificate of entitlement to right of abode
# 27448  Main applicant  Certificate of entitlement to right of abode
# 27449  Main applicant  Certificate of entitlement to right of abode
# 27450             All           Other settlement (indefinite leave)
# 27451             All           Other settlement (indefinite leave)
# 27452             All           Other settlement (indefinite leave)
# 27453             All           Other settlement (indefinite leave)
# 27454             All           Other settlement (indefinite leave)
# 27455             All           Other settlement (indefinite leave)
#
#       Resolution Applications
# 0            All       549934
# 1       Resolved       544208
# 2        Granted       428907
# 3        Refused       108812
# 4      Withdrawn         4888
# 5         Lapsed         1601
# 6            All       158424
# 7       Resolved       157409
# 8        Granted       121258
# 9        Refused        33704
# 10     Withdrawn         2111
# 11        Lapsed          336
# 12           All        72805
# 13      Resolved        70631
# 14       Granted        60550
# 15       Refused         8745
# 16     Withdrawn         1220
# 17        Lapsed          116
# 18           All        47737
# 19      Resolved        49921
# 20       Granted        29018
# 21       Refused        20236
# 22     Withdrawn          527
# 23        Lapsed          140
# 24           All        44870
# 25      Resolved        47049
# 26       Granted        26335
# 27       Refused        20068
# 28     Withdrawn          517
# 29        Lapsed          129
# ...          ...          ...
# 27426        All        34005
# 27427   Resolved        34154
# 27428    Granted        29480
# 27429    Refused         4569
# 27430  Withdrawn          103
# 27431     Lapsed            2
# 27432        All         4309
# 27433   Resolved         4346
# 27434    Granted         3914
# 27435    Refused          367
# 27436  Withdrawn           65
# 27437     Lapsed            0
# 27438        All         4541
# 27439   Resolved         4455
# 27440    Granted         4318
# 27441    Refused           34
# 27442  Withdrawn          103
# 27443     Lapsed            0
# 27444        All          353
# 27445   Resolved          399
# 27446    Granted          342
# 27447    Refused           48
# 27448  Withdrawn            9
# 27449     Lapsed            0
# 27450        All          253
# 27451   Resolved          476
# 27452    Granted          386
# 27453    Refused           81
# 27454  Withdrawn            9
# 27455     Lapsed            0
#
# [27456 rows x 7 columns]

# %% [markdown]
# Consider `*Total` to be `All` and rename `Applications` to `Value`

# %%
tidy.replace(r'^\*Total', 'All', regex=True, inplace=True)
tidy.rename(columns={'Applications': 'Value'}, inplace=True)
tidy
# Out:
#        Quarter                              Type          Broad category  \
# 0      2005 Q1                               All                     All
# 1      2005 Q1                               All                     All
# 2      2005 Q1                               All                     All
# 3      2005 Q1                               All                     All
# 4      2005 Q1                               All                     All
# 5      2005 Q1                               All                     All
# 6      2005 Q1  All (excl. Visitors and transit)                     All
# 7      2005 Q1  All (excl. Visitors and transit)                     All
# 8      2005 Q1  All (excl. Visitors and transit)                     All
# 9      2005 Q1  All (excl. Visitors and transit)                     All
# 10     2005 Q1  All (excl. Visitors and transit)                     All
# 11     2005 Q1  All (excl. Visitors and transit)                     All
# 12     2005 Q1                              Work                     All
# 13     2005 Q1                              Work                     All
# 14     2005 Q1                              Work                     All
# 15     2005 Q1                              Work                     All
# 16     2005 Q1                              Work                     All
# 17     2005 Q1                              Work                     All
# 18     2005 Q1                             Study                     All
# 19     2005 Q1                             Study                     All
# 20     2005 Q1                             Study                     All
# 21     2005 Q1                             Study                     All
# 22     2005 Q1                             Study                     All
# 23     2005 Q1                             Study                     All
# 24     2005 Q1                             Study                     All
# 25     2005 Q1                             Study                     All
# 26     2005 Q1                             Study                     All
# 27     2005 Q1                             Study                     All
# 28     2005 Q1                             Study                     All
# 29     2005 Q1                             Study                     All
# ...        ...                               ...                     ...
# 27426  2017 Q4                             Other   Other temporary visas
# 27427  2017 Q4                             Other   Other temporary visas
# 27428  2017 Q4                             Other   Other temporary visas
# 27429  2017 Q4                             Other   Other temporary visas
# 27430  2017 Q4                             Other   Other temporary visas
# 27431  2017 Q4                             Other   Other temporary visas
# 27432  2017 Q4                             Other   Other temporary visas
# 27433  2017 Q4                             Other   Other temporary visas
# 27434  2017 Q4                             Other   Other temporary visas
# 27435  2017 Q4                             Other   Other temporary visas
# 27436  2017 Q4                             Other   Other temporary visas
# 27437  2017 Q4                             Other   Other temporary visas
# 27438  2017 Q4                             Other   Other temporary visas
# 27439  2017 Q4                             Other   Other temporary visas
# 27440  2017 Q4                             Other   Other temporary visas
# 27441  2017 Q4                             Other   Other temporary visas
# 27442  2017 Q4                             Other   Other temporary visas
# 27443  2017 Q4                             Other   Other temporary visas
# 27444  2017 Q4                             Other  Other settlement visas
# 27445  2017 Q4                             Other  Other settlement visas
# 27446  2017 Q4                             Other  Other settlement visas
# 27447  2017 Q4                             Other  Other settlement visas
# 27448  2017 Q4                             Other  Other settlement visas
# 27449  2017 Q4                             Other  Other settlement visas
# 27450  2017 Q4                             Other  Other settlement visas
# 27451  2017 Q4                             Other  Other settlement visas
# 27452  2017 Q4                             Other  Other settlement visas
# 27453  2017 Q4                             Other  Other settlement visas
# 27454  2017 Q4                             Other  Other settlement visas
# 27455  2017 Q4                             Other  Other settlement visas
#
#        Applicant type                                      Category  \
# 0                 All                                           All
# 1                 All                                           All
# 2                 All                                           All
# 3                 All                                           All
# 4                 All                                           All
# 5                 All                                           All
# 6                 All          All (excluding visitors and transit)
# 7                 All          All (excluding visitors and transit)
# 8                 All          All (excluding visitors and transit)
# 9                 All          All (excluding visitors and transit)
# 10                All          All (excluding visitors and transit)
# 11                All          All (excluding visitors and transit)
# 12                All                                           All
# 13                All                                           All
# 14                All                                           All
# 15                All                                           All
# 16                All                                           All
# 17                All                                           All
# 18                All              All (including Short-term study)
# 19                All              All (including Short-term study)
# 20                All              All (including Short-term study)
# 21                All              All (including Short-term study)
# 22                All              All (including Short-term study)
# 23                All              All (including Short-term study)
# 24                All              All (excluding Short-term study)
# 25                All              All (excluding Short-term study)
# 26                All              All (excluding Short-term study)
# 27                All              All (excluding Short-term study)
# 28                All              All (excluding Short-term study)
# 29                All              All (excluding Short-term study)
# ...               ...                                           ...
# 27426       Dependant                                      Visitors
# 27427       Dependant                                      Visitors
# 27428       Dependant                                      Visitors
# 27429       Dependant                                      Visitors
# 27430       Dependant                                      Visitors
# 27431       Dependant                                      Visitors
# 27432             All                                       Transit
# 27433             All                                       Transit
# 27434             All                                       Transit
# 27435             All                                       Transit
# 27436             All                                       Transit
# 27437             All                                       Transit
# 27438             All                               Other temporary
# 27439             All                               Other temporary
# 27440             All                               Other temporary
# 27441             All                               Other temporary
# 27442             All                               Other temporary
# 27443             All                               Other temporary
# 27444  Main applicant  Certificate of entitlement to right of abode
# 27445  Main applicant  Certificate of entitlement to right of abode
# 27446  Main applicant  Certificate of entitlement to right of abode
# 27447  Main applicant  Certificate of entitlement to right of abode
# 27448  Main applicant  Certificate of entitlement to right of abode
# 27449  Main applicant  Certificate of entitlement to right of abode
# 27450             All           Other settlement (indefinite leave)
# 27451             All           Other settlement (indefinite leave)
# 27452             All           Other settlement (indefinite leave)
# 27453             All           Other settlement (indefinite leave)
# 27454             All           Other settlement (indefinite leave)
# 27455             All           Other settlement (indefinite leave)
#
#       Resolution   Value
# 0            All  549934
# 1       Resolved  544208
# 2        Granted  428907
# 3        Refused  108812
# 4      Withdrawn    4888
# 5         Lapsed    1601
# 6            All  158424
# 7       Resolved  157409
# 8        Granted  121258
# 9        Refused   33704
# 10     Withdrawn    2111
# 11        Lapsed     336
# 12           All   72805
# 13      Resolved   70631
# 14       Granted   60550
# 15       Refused    8745
# 16     Withdrawn    1220
# 17        Lapsed     116
# 18           All   47737
# 19      Resolved   49921
# 20       Granted   29018
# 21       Refused   20236
# 22     Withdrawn     527
# 23        Lapsed     140
# 24           All   44870
# 25      Resolved   47049
# 26       Granted   26335
# 27       Refused   20068
# 28     Withdrawn     517
# 29        Lapsed     129
# ...          ...     ...
# 27426        All   34005
# 27427   Resolved   34154
# 27428    Granted   29480
# 27429    Refused    4569
# 27430  Withdrawn     103
# 27431     Lapsed       2
# 27432        All    4309
# 27433   Resolved    4346
# 27434    Granted    3914
# 27435    Refused     367
# 27436  Withdrawn      65
# 27437     Lapsed       0
# 27438        All    4541
# 27439   Resolved    4455
# 27440    Granted    4318
# 27441    Refused      34
# 27442  Withdrawn     103
# 27443     Lapsed       0
# 27444        All     353
# 27445   Resolved     399
# 27446    Granted     342
# 27447    Refused      48
# 27448  Withdrawn       9
# 27449     Lapsed       0
# 27450        All     253
# 27451   Resolved     476
# 27452    Granted     386
# 27453    Refused      81
# 27454  Withdrawn       9
# 27455     Lapsed       0
#
# [27456 rows x 7 columns]

# %% [markdown]
# Turn the `Quarter` into a standard `Period`, e.g. quarter/2005-Q1

# %%
tidy.replace(
    {'Quarter': r'([0-9]{4}) (Q[1-4])'},
    {'Quarter': r'quarter/\1-\2'}, regex=True, inplace=True)
tidy.rename(
    columns={'Quarter': 'Period'}, inplace=True)
tidy
# Out:
#                 Period                              Type  \
# 0      quarter/2005-Q1                               All
# 1      quarter/2005-Q1                               All
# 2      quarter/2005-Q1                               All
# 3      quarter/2005-Q1                               All
# 4      quarter/2005-Q1                               All
# 5      quarter/2005-Q1                               All
# 6      quarter/2005-Q1  All (excl. Visitors and transit)
# 7      quarter/2005-Q1  All (excl. Visitors and transit)
# 8      quarter/2005-Q1  All (excl. Visitors and transit)
# 9      quarter/2005-Q1  All (excl. Visitors and transit)
# 10     quarter/2005-Q1  All (excl. Visitors and transit)
# 11     quarter/2005-Q1  All (excl. Visitors and transit)
# 12     quarter/2005-Q1                              Work
# 13     quarter/2005-Q1                              Work
# 14     quarter/2005-Q1                              Work
# 15     quarter/2005-Q1                              Work
# 16     quarter/2005-Q1                              Work
# 17     quarter/2005-Q1                              Work
# 18     quarter/2005-Q1                             Study
# 19     quarter/2005-Q1                             Study
# 20     quarter/2005-Q1                             Study
# 21     quarter/2005-Q1                             Study
# 22     quarter/2005-Q1                             Study
# 23     quarter/2005-Q1                             Study
# 24     quarter/2005-Q1                             Study
# 25     quarter/2005-Q1                             Study
# 26     quarter/2005-Q1                             Study
# 27     quarter/2005-Q1                             Study
# 28     quarter/2005-Q1                             Study
# 29     quarter/2005-Q1                             Study
# ...                ...                               ...
# 27426  quarter/2017-Q4                             Other
# 27427  quarter/2017-Q4                             Other
# 27428  quarter/2017-Q4                             Other
# 27429  quarter/2017-Q4                             Other
# 27430  quarter/2017-Q4                             Other
# 27431  quarter/2017-Q4                             Other
# 27432  quarter/2017-Q4                             Other
# 27433  quarter/2017-Q4                             Other
# 27434  quarter/2017-Q4                             Other
# 27435  quarter/2017-Q4                             Other
# 27436  quarter/2017-Q4                             Other
# 27437  quarter/2017-Q4                             Other
# 27438  quarter/2017-Q4                             Other
# 27439  quarter/2017-Q4                             Other
# 27440  quarter/2017-Q4                             Other
# 27441  quarter/2017-Q4                             Other
# 27442  quarter/2017-Q4                             Other
# 27443  quarter/2017-Q4                             Other
# 27444  quarter/2017-Q4                             Other
# 27445  quarter/2017-Q4                             Other
# 27446  quarter/2017-Q4                             Other
# 27447  quarter/2017-Q4                             Other
# 27448  quarter/2017-Q4                             Other
# 27449  quarter/2017-Q4                             Other
# 27450  quarter/2017-Q4                             Other
# 27451  quarter/2017-Q4                             Other
# 27452  quarter/2017-Q4                             Other
# 27453  quarter/2017-Q4                             Other
# 27454  quarter/2017-Q4                             Other
# 27455  quarter/2017-Q4                             Other
#
#                Broad category  Applicant type  \
# 0                         All             All
# 1                         All             All
# 2                         All             All
# 3                         All             All
# 4                         All             All
# 5                         All             All
# 6                         All             All
# 7                         All             All
# 8                         All             All
# 9                         All             All
# 10                        All             All
# 11                        All             All
# 12                        All             All
# 13                        All             All
# 14                        All             All
# 15                        All             All
# 16                        All             All
# 17                        All             All
# 18                        All             All
# 19                        All             All
# 20                        All             All
# 21                        All             All
# 22                        All             All
# 23                        All             All
# 24                        All             All
# 25                        All             All
# 26                        All             All
# 27                        All             All
# 28                        All             All
# 29                        All             All
# ...                       ...             ...
# 27426   Other temporary visas       Dependant
# 27427   Other temporary visas       Dependant
# 27428   Other temporary visas       Dependant
# 27429   Other temporary visas       Dependant
# 27430   Other temporary visas       Dependant
# 27431   Other temporary visas       Dependant
# 27432   Other temporary visas             All
# 27433   Other temporary visas             All
# 27434   Other temporary visas             All
# 27435   Other temporary visas             All
# 27436   Other temporary visas             All
# 27437   Other temporary visas             All
# 27438   Other temporary visas             All
# 27439   Other temporary visas             All
# 27440   Other temporary visas             All
# 27441   Other temporary visas             All
# 27442   Other temporary visas             All
# 27443   Other temporary visas             All
# 27444  Other settlement visas  Main applicant
# 27445  Other settlement visas  Main applicant
# 27446  Other settlement visas  Main applicant
# 27447  Other settlement visas  Main applicant
# 27448  Other settlement visas  Main applicant
# 27449  Other settlement visas  Main applicant
# 27450  Other settlement visas             All
# 27451  Other settlement visas             All
# 27452  Other settlement visas             All
# 27453  Other settlement visas             All
# 27454  Other settlement visas             All
# 27455  Other settlement visas             All
#
#                                            Category Resolution   Value
# 0                                               All        All  549934
# 1                                               All   Resolved  544208
# 2                                               All    Granted  428907
# 3                                               All    Refused  108812
# 4                                               All  Withdrawn    4888
# 5                                               All     Lapsed    1601
# 6              All (excluding visitors and transit)        All  158424
# 7              All (excluding visitors and transit)   Resolved  157409
# 8              All (excluding visitors and transit)    Granted  121258
# 9              All (excluding visitors and transit)    Refused   33704
# 10             All (excluding visitors and transit)  Withdrawn    2111
# 11             All (excluding visitors and transit)     Lapsed     336
# 12                                              All        All   72805
# 13                                              All   Resolved   70631
# 14                                              All    Granted   60550
# 15                                              All    Refused    8745
# 16                                              All  Withdrawn    1220
# 17                                              All     Lapsed     116
# 18                 All (including Short-term study)        All   47737
# 19                 All (including Short-term study)   Resolved   49921
# 20                 All (including Short-term study)    Granted   29018
# 21                 All (including Short-term study)    Refused   20236
# 22                 All (including Short-term study)  Withdrawn     527
# 23                 All (including Short-term study)     Lapsed     140
# 24                 All (excluding Short-term study)        All   44870
# 25                 All (excluding Short-term study)   Resolved   47049
# 26                 All (excluding Short-term study)    Granted   26335
# 27                 All (excluding Short-term study)    Refused   20068
# 28                 All (excluding Short-term study)  Withdrawn     517
# 29                 All (excluding Short-term study)     Lapsed     129
# ...                                             ...        ...     ...
# 27426                                      Visitors        All   34005
# 27427                                      Visitors   Resolved   34154
# 27428                                      Visitors    Granted   29480
# 27429                                      Visitors    Refused    4569
# 27430                                      Visitors  Withdrawn     103
# 27431                                      Visitors     Lapsed       2
# 27432                                       Transit        All    4309
# 27433                                       Transit   Resolved    4346
# 27434                                       Transit    Granted    3914
# 27435                                       Transit    Refused     367
# 27436                                       Transit  Withdrawn      65
# 27437                                       Transit     Lapsed       0
# 27438                               Other temporary        All    4541
# 27439                               Other temporary   Resolved    4455
# 27440                               Other temporary    Granted    4318
# 27441                               Other temporary    Refused      34
# 27442                               Other temporary  Withdrawn     103
# 27443                               Other temporary     Lapsed       0
# 27444  Certificate of entitlement to right of abode        All     353
# 27445  Certificate of entitlement to right of abode   Resolved     399
# 27446  Certificate of entitlement to right of abode    Granted     342
# 27447  Certificate of entitlement to right of abode    Refused      48
# 27448  Certificate of entitlement to right of abode  Withdrawn       9
# 27449  Certificate of entitlement to right of abode     Lapsed       0
# 27450           Other settlement (indefinite leave)        All     253
# 27451           Other settlement (indefinite leave)   Resolved     476
# 27452           Other settlement (indefinite leave)    Granted     386
# 27453           Other settlement (indefinite leave)    Refused      81
# 27454           Other settlement (indefinite leave)  Withdrawn       9
# 27455           Other settlement (indefinite leave)     Lapsed       0
#
# [27456 rows x 7 columns]

# %% [markdown]
# Todo: data markers, `z` means `not applicable` and `:` means `not available`

# %%
import numpy as np
tidy.drop(tidy.index[~tidy['Value'].map(np.isreal)], inplace=True)
tidy['Value'] = tidy['Value'].astype(int)
tidy
# Out:
#                 Period                              Type  \
# 0      quarter/2005-Q1                               All
# 1      quarter/2005-Q1                               All
# 2      quarter/2005-Q1                               All
# 3      quarter/2005-Q1                               All
# 4      quarter/2005-Q1                               All
# 5      quarter/2005-Q1                               All
# 6      quarter/2005-Q1  All (excl. Visitors and transit)
# 7      quarter/2005-Q1  All (excl. Visitors and transit)
# 8      quarter/2005-Q1  All (excl. Visitors and transit)
# 9      quarter/2005-Q1  All (excl. Visitors and transit)
# 10     quarter/2005-Q1  All (excl. Visitors and transit)
# 11     quarter/2005-Q1  All (excl. Visitors and transit)
# 12     quarter/2005-Q1                              Work
# 13     quarter/2005-Q1                              Work
# 14     quarter/2005-Q1                              Work
# 15     quarter/2005-Q1                              Work
# 16     quarter/2005-Q1                              Work
# 17     quarter/2005-Q1                              Work
# 18     quarter/2005-Q1                             Study
# 19     quarter/2005-Q1                             Study
# 20     quarter/2005-Q1                             Study
# 21     quarter/2005-Q1                             Study
# 22     quarter/2005-Q1                             Study
# 23     quarter/2005-Q1                             Study
# 24     quarter/2005-Q1                             Study
# 25     quarter/2005-Q1                             Study
# 26     quarter/2005-Q1                             Study
# 27     quarter/2005-Q1                             Study
# 28     quarter/2005-Q1                             Study
# 29     quarter/2005-Q1                             Study
# ...                ...                               ...
# 27426  quarter/2017-Q4                             Other
# 27427  quarter/2017-Q4                             Other
# 27428  quarter/2017-Q4                             Other
# 27429  quarter/2017-Q4                             Other
# 27430  quarter/2017-Q4                             Other
# 27431  quarter/2017-Q4                             Other
# 27432  quarter/2017-Q4                             Other
# 27433  quarter/2017-Q4                             Other
# 27434  quarter/2017-Q4                             Other
# 27435  quarter/2017-Q4                             Other
# 27436  quarter/2017-Q4                             Other
# 27437  quarter/2017-Q4                             Other
# 27438  quarter/2017-Q4                             Other
# 27439  quarter/2017-Q4                             Other
# 27440  quarter/2017-Q4                             Other
# 27441  quarter/2017-Q4                             Other
# 27442  quarter/2017-Q4                             Other
# 27443  quarter/2017-Q4                             Other
# 27444  quarter/2017-Q4                             Other
# 27445  quarter/2017-Q4                             Other
# 27446  quarter/2017-Q4                             Other
# 27447  quarter/2017-Q4                             Other
# 27448  quarter/2017-Q4                             Other
# 27449  quarter/2017-Q4                             Other
# 27450  quarter/2017-Q4                             Other
# 27451  quarter/2017-Q4                             Other
# 27452  quarter/2017-Q4                             Other
# 27453  quarter/2017-Q4                             Other
# 27454  quarter/2017-Q4                             Other
# 27455  quarter/2017-Q4                             Other
#
#                Broad category  Applicant type  \
# 0                         All             All
# 1                         All             All
# 2                         All             All
# 3                         All             All
# 4                         All             All
# 5                         All             All
# 6                         All             All
# 7                         All             All
# 8                         All             All
# 9                         All             All
# 10                        All             All
# 11                        All             All
# 12                        All             All
# 13                        All             All
# 14                        All             All
# 15                        All             All
# 16                        All             All
# 17                        All             All
# 18                        All             All
# 19                        All             All
# 20                        All             All
# 21                        All             All
# 22                        All             All
# 23                        All             All
# 24                        All             All
# 25                        All             All
# 26                        All             All
# 27                        All             All
# 28                        All             All
# 29                        All             All
# ...                       ...             ...
# 27426   Other temporary visas       Dependant
# 27427   Other temporary visas       Dependant
# 27428   Other temporary visas       Dependant
# 27429   Other temporary visas       Dependant
# 27430   Other temporary visas       Dependant
# 27431   Other temporary visas       Dependant
# 27432   Other temporary visas             All
# 27433   Other temporary visas             All
# 27434   Other temporary visas             All
# 27435   Other temporary visas             All
# 27436   Other temporary visas             All
# 27437   Other temporary visas             All
# 27438   Other temporary visas             All
# 27439   Other temporary visas             All
# 27440   Other temporary visas             All
# 27441   Other temporary visas             All
# 27442   Other temporary visas             All
# 27443   Other temporary visas             All
# 27444  Other settlement visas  Main applicant
# 27445  Other settlement visas  Main applicant
# 27446  Other settlement visas  Main applicant
# 27447  Other settlement visas  Main applicant
# 27448  Other settlement visas  Main applicant
# 27449  Other settlement visas  Main applicant
# 27450  Other settlement visas             All
# 27451  Other settlement visas             All
# 27452  Other settlement visas             All
# 27453  Other settlement visas             All
# 27454  Other settlement visas             All
# 27455  Other settlement visas             All
#
#                                            Category Resolution   Value
# 0                                               All        All  549934
# 1                                               All   Resolved  544208
# 2                                               All    Granted  428907
# 3                                               All    Refused  108812
# 4                                               All  Withdrawn    4888
# 5                                               All     Lapsed    1601
# 6              All (excluding visitors and transit)        All  158424
# 7              All (excluding visitors and transit)   Resolved  157409
# 8              All (excluding visitors and transit)    Granted  121258
# 9              All (excluding visitors and transit)    Refused   33704
# 10             All (excluding visitors and transit)  Withdrawn    2111
# 11             All (excluding visitors and transit)     Lapsed     336
# 12                                              All        All   72805
# 13                                              All   Resolved   70631
# 14                                              All    Granted   60550
# 15                                              All    Refused    8745
# 16                                              All  Withdrawn    1220
# 17                                              All     Lapsed     116
# 18                 All (including Short-term study)        All   47737
# 19                 All (including Short-term study)   Resolved   49921
# 20                 All (including Short-term study)    Granted   29018
# 21                 All (including Short-term study)    Refused   20236
# 22                 All (including Short-term study)  Withdrawn     527
# 23                 All (including Short-term study)     Lapsed     140
# 24                 All (excluding Short-term study)        All   44870
# 25                 All (excluding Short-term study)   Resolved   47049
# 26                 All (excluding Short-term study)    Granted   26335
# 27                 All (excluding Short-term study)    Refused   20068
# 28                 All (excluding Short-term study)  Withdrawn     517
# 29                 All (excluding Short-term study)     Lapsed     129
# ...                                             ...        ...     ...
# 27426                                      Visitors        All   34005
# 27427                                      Visitors   Resolved   34154
# 27428                                      Visitors    Granted   29480
# 27429                                      Visitors    Refused    4569
# 27430                                      Visitors  Withdrawn     103
# 27431                                      Visitors     Lapsed       2
# 27432                                       Transit        All    4309
# 27433                                       Transit   Resolved    4346
# 27434                                       Transit    Granted    3914
# 27435                                       Transit    Refused     367
# 27436                                       Transit  Withdrawn      65
# 27437                                       Transit     Lapsed       0
# 27438                               Other temporary        All    4541
# 27439                               Other temporary   Resolved    4455
# 27440                               Other temporary    Granted    4318
# 27441                               Other temporary    Refused      34
# 27442                               Other temporary  Withdrawn     103
# 27443                               Other temporary     Lapsed       0
# 27444  Certificate of entitlement to right of abode        All     353
# 27445  Certificate of entitlement to right of abode   Resolved     399
# 27446  Certificate of entitlement to right of abode    Granted     342
# 27447  Certificate of entitlement to right of abode    Refused      48
# 27448  Certificate of entitlement to right of abode  Withdrawn       9
# 27449  Certificate of entitlement to right of abode     Lapsed       0
# 27450           Other settlement (indefinite leave)        All     253
# 27451           Other settlement (indefinite leave)   Resolved     476
# 27452           Other settlement (indefinite leave)    Granted     386
# 27453           Other settlement (indefinite leave)    Refused      81
# 27454           Other settlement (indefinite leave)  Withdrawn       9
# 27455           Other settlement (indefinite leave)     Lapsed       0
#
# [22017 rows x 7 columns]

# %% [markdown]
# Category and broad category need to go into a codelist.

# %%
unique_pairs = set(zip(tidy['Broad category'], tidy['Category']))
display(unique_pairs)

# Where category = 'All', the category should be the 'broad category'
unique_pairs = [(broad, cat if cat != 'All' else broad) for (broad, cat) in unique_pairs]

# does the category uniquely determine the broad category?
cat2broad = {}
for (broad, cat) in unique_pairs:
    if cat in cat2broad:
        assert cat2broad[cat] == broad, f'{broad} != {cat2broad[cat]}'
    else:
        cat2broad[cat] = broad
        
# assumption is ok, so work out a codelist

codelist = [('All', 'all', '')]
for broad in sorted(set(cat2broad.values())):
    if broad == 'All':
        continue
    codelist.append((broad, pathify(broad), pathify('All')))
for cat, broad in sorted(cat2broad.items()):
    if cat == 'All' or cat == broad:
        continue
    codelist.append((cat, pathify(cat), pathify(broad)))
    
codelist
# Out:
# {('All', 'All'),
#  ('All', 'All (excluding Short-term study)'),
#  ('All', 'All (excluding Visitors and Transit)'),
#  ('All', 'All (excluding visitors and transit)'),
#  ('All', 'All (including Short-term study)'),
#  ('Dep. joining or accompanying', 'Joining or accompanying: Child'),
#  ('Dep. joining or accompanying', 'Joining or accompanying: Other'),
#  ('Dep. joining or accompanying', 'Joining or accompanying: Partner'),
#  ('Family', 'Family: Child'),
#  ('Family', 'Family: Child (for immediate settlement)'),
#  ('Family', 'Family: Child (for settlement)'),
#  ('Family', 'Family: Other'),
#  ('Family', 'Family: Other (for immediate settlement)'),
#  ('Family', 'Family: Other (for settlement)'),
#  ('Family', 'Family: Partner'),
#  ('Family', 'Family: Partner (for immediate settlement)'),
#  ('Family', 'Family: Partner (for settlement)'),
#  ('Non-PBS', 'All'),
#  ('Non-PBS', 'Domestic workers in Private Households'),
#  ('Non-PBS', 'Other permit free employment - Non-PBS'),
#  ('Non-PBS', 'Short-term study (previously Student Visitors)'),
#  ('Non-PBS', 'UK Ancestry'),
#  ('Other', 'All'),
#  ('Other', 'Other permit free employment not allocated'),
#  ('Other settlement visas', 'Certificate of entitlement to right of abode'),
#  ('Other settlement visas', 'Other settlement (indefinite leave)'),
#  ('Other temporary visas', 'EEA family permits'),
#  ('Other temporary visas', 'Other temporary'),
#  ('Other temporary visas', 'Transit'),
#  ('Other temporary visas', 'Visitors'),
#  ('Tier 1 & pre-PBS equivalent', 'All'),
#  ('Tier 1 & pre-PBS equivalent', 'International Graduates Scheme'),
#  ('Tier 1 & pre-PBS equivalent', 'Other permit free employment - High value'),
#  ('Tier 1 & pre-PBS equivalent',
#   'Other permit free employment - Highly skilled'),
#  ('Tier 1 & pre-PBS equivalent', 'Tier 1 - Entrepreneurs'),
#  ('Tier 1 & pre-PBS equivalent', 'Tier 1 - Exceptional Talent'),
#  ('Tier 1 & pre-PBS equivalent', 'Tier 1 - General'),
#  ('Tier 1 & pre-PBS equivalent', 'Tier 1 - Graduate entrepreneurs'),
#  ('Tier 1 & pre-PBS equivalent', 'Tier 1 - Investors'),
#  ('Tier 1 & pre-PBS equivalent', 'Tier 1 - Other'),
#  ('Tier 1 & pre-PBS equivalent', 'Tier 1 - Post Study'),
#  ('Tier 2 & pre-PBS equivalent', 'All'),
#  ('Tier 2 & pre-PBS equivalent', 'Ministers of religion or missionary'),
#  ('Tier 2 & pre-PBS equivalent', 'Other permit free employment - skilled'),
#  ('Tier 2 & pre-PBS equivalent', 'Tier 2 - Dependant'),
#  ('Tier 2 & pre-PBS equivalent', 'Tier 2 - General'),
#  ('Tier 2 & pre-PBS equivalent', 'Tier 2 - Intra Company Transfers'),
#  ('Tier 2 & pre-PBS equivalent', 'Tier 2 - Intra Company Transfers Long Term'),
#  ('Tier 2 & pre-PBS equivalent',
#   'Tier 2 - Intra Company Transfers Short Term'),
#  ('Tier 2 & pre-PBS equivalent', 'Tier 2 - Ministers of Religion'),
#  ('Tier 2 & pre-PBS equivalent', 'Tier 2 - Sportsperson'),
#  ('Tier 2 & pre-PBS equivalent', 'Tier 2 Dependant'),
#  ('Tier 2 & pre-PBS equivalent', 'Work Permit Holders'),
#  ('Tier 4 & pre-PBS equivalent', 'All'),
#  ('Tier 4 & pre-PBS equivalent', 'Students'),
#  ('Tier 4 & pre-PBS equivalent', 'Tier 4 - Child student'),
#  ('Tier 4 & pre-PBS equivalent', 'Tier 4 - General student'),
#  ('Tier 4 & pre-PBS equivalent', 'Trainees - doctors & dentists'),
#  ('Tier 5 & pre-PBS equivalent', 'All'),
#  ('Tier 5 & pre-PBS equivalent', 'Other permit free employment'),
#  ('Tier 5 & pre-PBS equivalent', 'Private servants in Diplomatic Households'),
#  ('Tier 5 & pre-PBS equivalent', 'Religious workers'),
#  ('Tier 5 & pre-PBS equivalent', 'Tier 5 - Charity Workers'),
#  ('Tier 5 & pre-PBS equivalent', 'Tier 5 - Creative and Sporting'),
#  ('Tier 5 & pre-PBS equivalent', 'Tier 5 - Dependant'),
#  ('Tier 5 & pre-PBS equivalent', 'Tier 5 - Government Authorised Exchange'),
#  ('Tier 5 & pre-PBS equivalent', 'Tier 5 - International Agreement'),
#  ('Tier 5 & pre-PBS equivalent', 'Tier 5 - Religious Workers'),
#  ('Tier 5 & pre-PBS equivalent', 'Tier 5 - Youth Mobility'),
#  ('Tier 5 & pre-PBS equivalent', 'Tier 5 Dependant'),
#  ('Tier 5 & pre-PBS equivalent', 'Working holidaymakers')}
# [('All', 'all', ''),
#  ('Dep. joining or accompanying', 'dep-joining-or-accompanying', 'all'),
#  ('Family', 'family', 'all'),
#  ('Non-PBS', 'non-pbs', 'all'),
#  ('Other', 'other', 'all'),
#  ('Other settlement visas', 'other-settlement-visas', 'all'),
#  ('Other temporary visas', 'other-temporary-visas', 'all'),
#  ('Tier 1 & pre-PBS equivalent', 'tier-1-pre-pbs-equivalent', 'all'),
#  ('Tier 2 & pre-PBS equivalent', 'tier-2-pre-pbs-equivalent', 'all'),
#  ('Tier 4 & pre-PBS equivalent', 'tier-4-pre-pbs-equivalent', 'all'),
#  ('Tier 5 & pre-PBS equivalent', 'tier-5-pre-pbs-equivalent', 'all'),
#  ('All (excluding Short-term study)',
#   'all-excluding-short-term-study-',
#   'all'),
#  ('All (excluding Visitors and Transit)',
#   'all-excluding-visitors-and-transit-',
#   'all'),
#  ('All (excluding visitors and transit)',
#   'all-excluding-visitors-and-transit-',
#   'all'),
#  ('All (including Short-term study)',
#   'all-including-short-term-study-',
#   'all'),
#  ('Certificate of entitlement to right of abode',
#   'certificate-of-entitlement-to-right-of-abode',
#   'other-settlement-visas'),
#  ('Domestic workers in Private Households',
#   'domestic-workers-in-private-households',
#   'non-pbs'),
#  ('EEA family permits', 'eea-family-permits', 'other-temporary-visas'),
#  ('Family: Child', 'family-child', 'family'),
#  ('Family: Child (for immediate settlement)',
#   'family-child-for-immediate-settlement-',
#   'family'),
#  ('Family: Child (for settlement)', 'family-child-for-settlement-', 'family'),
#  ('Family: Other', 'family-other', 'family'),
#  ('Family: Other (for immediate settlement)',
#   'family-other-for-immediate-settlement-',
#   'family'),
#  ('Family: Other (for settlement)', 'family-other-for-settlement-', 'family'),
#  ('Family: Partner', 'family-partner', 'family'),
#  ('Family: Partner (for immediate settlement)',
#   'family-partner-for-immediate-settlement-',
#   'family'),
#  ('Family: Partner (for settlement)',
#   'family-partner-for-settlement-',
#   'family'),
#  ('International Graduates Scheme',
#   'international-graduates-scheme',
#   'tier-1-pre-pbs-equivalent'),
#  ('Joining or accompanying: Child',
#   'joining-or-accompanying-child',
#   'dep-joining-or-accompanying'),
#  ('Joining or accompanying: Other',
#   'joining-or-accompanying-other',
#   'dep-joining-or-accompanying'),
#  ('Joining or accompanying: Partner',
#   'joining-or-accompanying-partner',
#   'dep-joining-or-accompanying'),
#  ('Ministers of religion or missionary',
#   'ministers-of-religion-or-missionary',
#   'tier-2-pre-pbs-equivalent'),
#  ('Other permit free employment',
#   'other-permit-free-employment',
#   'tier-5-pre-pbs-equivalent'),
#  ('Other permit free employment - High value',
#   'other-permit-free-employment-high-value',
#   'tier-1-pre-pbs-equivalent'),
#  ('Other permit free employment - Highly skilled',
#   'other-permit-free-employment-highly-skilled',
#   'tier-1-pre-pbs-equivalent'),
#  ('Other permit free employment - Non-PBS',
#   'other-permit-free-employment-non-pbs',
#   'non-pbs'),
#  ('Other permit free employment - skilled',
#   'other-permit-free-employment-skilled',
#   'tier-2-pre-pbs-equivalent'),
#  ('Other permit free employment not allocated',
#   'other-permit-free-employment-not-allocated',
#   'other'),
#  ('Other settlement (indefinite leave)',
#   'other-settlement-indefinite-leave-',
#   'other-settlement-visas'),
#  ('Other temporary', 'other-temporary', 'other-temporary-visas'),
#  ('Private servants in Diplomatic Households',
#   'private-servants-in-diplomatic-households',
#   'tier-5-pre-pbs-equivalent'),
#  ('Religious workers', 'religious-workers', 'tier-5-pre-pbs-equivalent'),
#  ('Short-term study (previously Student Visitors)',
#   'short-term-study-previously-student-visitors-',
#   'non-pbs'),
#  ('Students', 'students', 'tier-4-pre-pbs-equivalent'),
#  ('Tier 1 - Entrepreneurs',
#   'tier-1-entrepreneurs',
#   'tier-1-pre-pbs-equivalent'),
#  ('Tier 1 - Exceptional Talent',
#   'tier-1-exceptional-talent',
#   'tier-1-pre-pbs-equivalent'),
#  ('Tier 1 - General', 'tier-1-general', 'tier-1-pre-pbs-equivalent'),
#  ('Tier 1 - Graduate entrepreneurs',
#   'tier-1-graduate-entrepreneurs',
#   'tier-1-pre-pbs-equivalent'),
#  ('Tier 1 - Investors', 'tier-1-investors', 'tier-1-pre-pbs-equivalent'),
#  ('Tier 1 - Other', 'tier-1-other', 'tier-1-pre-pbs-equivalent'),
#  ('Tier 1 - Post Study', 'tier-1-post-study', 'tier-1-pre-pbs-equivalent'),
#  ('Tier 2 - Dependant', 'tier-2-dependant', 'tier-2-pre-pbs-equivalent'),
#  ('Tier 2 - General', 'tier-2-general', 'tier-2-pre-pbs-equivalent'),
#  ('Tier 2 - Intra Company Transfers',
#   'tier-2-intra-company-transfers',
#   'tier-2-pre-pbs-equivalent'),
#  ('Tier 2 - Intra Company Transfers Long Term',
#   'tier-2-intra-company-transfers-long-term',
#   'tier-2-pre-pbs-equivalent'),
#  ('Tier 2 - Intra Company Transfers Short Term',
#   'tier-2-intra-company-transfers-short-term',
#   'tier-2-pre-pbs-equivalent'),
#  ('Tier 2 - Ministers of Religion',
#   'tier-2-ministers-of-religion',
#   'tier-2-pre-pbs-equivalent'),
#  ('Tier 2 - Sportsperson', 'tier-2-sportsperson', 'tier-2-pre-pbs-equivalent'),
#  ('Tier 2 Dependant', 'tier-2-dependant', 'tier-2-pre-pbs-equivalent'),
#  ('Tier 4 - Child student',
#   'tier-4-child-student',
#   'tier-4-pre-pbs-equivalent'),
#  ('Tier 4 - General student',
#   'tier-4-general-student',
#   'tier-4-pre-pbs-equivalent'),
#  ('Tier 5 - Charity Workers',
#   'tier-5-charity-workers',
#   'tier-5-pre-pbs-equivalent'),
#  ('Tier 5 - Creative and Sporting',
#   'tier-5-creative-and-sporting',
#   'tier-5-pre-pbs-equivalent'),
#  ('Tier 5 - Dependant', 'tier-5-dependant', 'tier-5-pre-pbs-equivalent'),
#  ('Tier 5 - Government Authorised Exchange',
#   'tier-5-government-authorised-exchange',
#   'tier-5-pre-pbs-equivalent'),
#  ('Tier 5 - International Agreement',
#   'tier-5-international-agreement',
#   'tier-5-pre-pbs-equivalent'),
#  ('Tier 5 - Religious Workers',
#   'tier-5-religious-workers',
#   'tier-5-pre-pbs-equivalent'),
#  ('Tier 5 - Youth Mobility',
#   'tier-5-youth-mobility',
#   'tier-5-pre-pbs-equivalent'),
#  ('Tier 5 Dependant', 'tier-5-dependant', 'tier-5-pre-pbs-equivalent'),
#  ('Trainees - doctors & dentists',
#   'trainees-doctors-dentists',
#   'tier-4-pre-pbs-equivalent'),
#  ('Transit', 'transit', 'other-temporary-visas'),
#  ('UK Ancestry', 'uk-ancestry', 'non-pbs'),
#  ('Visitors', 'visitors', 'other-temporary-visas'),
#  ('Work Permit Holders', 'work-permit-holders', 'tier-2-pre-pbs-equivalent'),
#  ('Working holidaymakers',
#   'working-holidaymakers',
#   'tier-5-pre-pbs-equivalent')]

# %%
# and write out the codelist and update the tidy table.

tidy['Application category'] = tidy.apply(
    lambda row: row['Category'] if row['Category'] != 'All' else row['Broad category'],
    axis=1)
tidy.drop(columns=['Category', 'Broad category'], inplace=True)

codelist_df = pd.DataFrame.from_records(codelist,
                                       columns=('Label', 'Notation', 'Parent Notation'))
codelist_df['Sort Priority'] = codelist_df.index + 1

from pathlib import Path
out = Path('out')
out.mkdir(exist_ok=True)

codelist_df.to_csv(out / 'ho-applicant-categories.csv', index=False)

# Type -> Application type
tidy.rename(columns={'Type': 'Application type'}, inplace=True)
tidy
# Out:
#                 Period                  Application type  Applicant type  \
# 0      quarter/2005-Q1                               All             All
# 1      quarter/2005-Q1                               All             All
# 2      quarter/2005-Q1                               All             All
# 3      quarter/2005-Q1                               All             All
# 4      quarter/2005-Q1                               All             All
# 5      quarter/2005-Q1                               All             All
# 6      quarter/2005-Q1  All (excl. Visitors and transit)             All
# 7      quarter/2005-Q1  All (excl. Visitors and transit)             All
# 8      quarter/2005-Q1  All (excl. Visitors and transit)             All
# 9      quarter/2005-Q1  All (excl. Visitors and transit)             All
# 10     quarter/2005-Q1  All (excl. Visitors and transit)             All
# 11     quarter/2005-Q1  All (excl. Visitors and transit)             All
# 12     quarter/2005-Q1                              Work             All
# 13     quarter/2005-Q1                              Work             All
# 14     quarter/2005-Q1                              Work             All
# 15     quarter/2005-Q1                              Work             All
# 16     quarter/2005-Q1                              Work             All
# 17     quarter/2005-Q1                              Work             All
# 18     quarter/2005-Q1                             Study             All
# 19     quarter/2005-Q1                             Study             All
# 20     quarter/2005-Q1                             Study             All
# 21     quarter/2005-Q1                             Study             All
# 22     quarter/2005-Q1                             Study             All
# 23     quarter/2005-Q1                             Study             All
# 24     quarter/2005-Q1                             Study             All
# 25     quarter/2005-Q1                             Study             All
# 26     quarter/2005-Q1                             Study             All
# 27     quarter/2005-Q1                             Study             All
# 28     quarter/2005-Q1                             Study             All
# 29     quarter/2005-Q1                             Study             All
# ...                ...                               ...             ...
# 27426  quarter/2017-Q4                             Other       Dependant
# 27427  quarter/2017-Q4                             Other       Dependant
# 27428  quarter/2017-Q4                             Other       Dependant
# 27429  quarter/2017-Q4                             Other       Dependant
# 27430  quarter/2017-Q4                             Other       Dependant
# 27431  quarter/2017-Q4                             Other       Dependant
# 27432  quarter/2017-Q4                             Other             All
# 27433  quarter/2017-Q4                             Other             All
# 27434  quarter/2017-Q4                             Other             All
# 27435  quarter/2017-Q4                             Other             All
# 27436  quarter/2017-Q4                             Other             All
# 27437  quarter/2017-Q4                             Other             All
# 27438  quarter/2017-Q4                             Other             All
# 27439  quarter/2017-Q4                             Other             All
# 27440  quarter/2017-Q4                             Other             All
# 27441  quarter/2017-Q4                             Other             All
# 27442  quarter/2017-Q4                             Other             All
# 27443  quarter/2017-Q4                             Other             All
# 27444  quarter/2017-Q4                             Other  Main applicant
# 27445  quarter/2017-Q4                             Other  Main applicant
# 27446  quarter/2017-Q4                             Other  Main applicant
# 27447  quarter/2017-Q4                             Other  Main applicant
# 27448  quarter/2017-Q4                             Other  Main applicant
# 27449  quarter/2017-Q4                             Other  Main applicant
# 27450  quarter/2017-Q4                             Other             All
# 27451  quarter/2017-Q4                             Other             All
# 27452  quarter/2017-Q4                             Other             All
# 27453  quarter/2017-Q4                             Other             All
# 27454  quarter/2017-Q4                             Other             All
# 27455  quarter/2017-Q4                             Other             All
#
#       Resolution   Value                          Application category
# 0            All  549934                                           All
# 1       Resolved  544208                                           All
# 2        Granted  428907                                           All
# 3        Refused  108812                                           All
# 4      Withdrawn    4888                                           All
# 5         Lapsed    1601                                           All
# 6            All  158424          All (excluding visitors and transit)
# 7       Resolved  157409          All (excluding visitors and transit)
# 8        Granted  121258          All (excluding visitors and transit)
# 9        Refused   33704          All (excluding visitors and transit)
# 10     Withdrawn    2111          All (excluding visitors and transit)
# 11        Lapsed     336          All (excluding visitors and transit)
# 12           All   72805                                           All
# 13      Resolved   70631                                           All
# 14       Granted   60550                                           All
# 15       Refused    8745                                           All
# 16     Withdrawn    1220                                           All
# 17        Lapsed     116                                           All
# 18           All   47737              All (including Short-term study)
# 19      Resolved   49921              All (including Short-term study)
# 20       Granted   29018              All (including Short-term study)
# 21       Refused   20236              All (including Short-term study)
# 22     Withdrawn     527              All (including Short-term study)
# 23        Lapsed     140              All (including Short-term study)
# 24           All   44870              All (excluding Short-term study)
# 25      Resolved   47049              All (excluding Short-term study)
# 26       Granted   26335              All (excluding Short-term study)
# 27       Refused   20068              All (excluding Short-term study)
# 28     Withdrawn     517              All (excluding Short-term study)
# 29        Lapsed     129              All (excluding Short-term study)
# ...          ...     ...                                           ...
# 27426        All   34005                                      Visitors
# 27427   Resolved   34154                                      Visitors
# 27428    Granted   29480                                      Visitors
# 27429    Refused    4569                                      Visitors
# 27430  Withdrawn     103                                      Visitors
# 27431     Lapsed       2                                      Visitors
# 27432        All    4309                                       Transit
# 27433   Resolved    4346                                       Transit
# 27434    Granted    3914                                       Transit
# 27435    Refused     367                                       Transit
# 27436  Withdrawn      65                                       Transit
# 27437     Lapsed       0                                       Transit
# 27438        All    4541                               Other temporary
# 27439   Resolved    4455                               Other temporary
# 27440    Granted    4318                               Other temporary
# 27441    Refused      34                               Other temporary
# 27442  Withdrawn     103                               Other temporary
# 27443     Lapsed       0                               Other temporary
# 27444        All     353  Certificate of entitlement to right of abode
# 27445   Resolved     399  Certificate of entitlement to right of abode
# 27446    Granted     342  Certificate of entitlement to right of abode
# 27447    Refused      48  Certificate of entitlement to right of abode
# 27448  Withdrawn       9  Certificate of entitlement to right of abode
# 27449     Lapsed       0  Certificate of entitlement to right of abode
# 27450        All     253           Other settlement (indefinite leave)
# 27451   Resolved     476           Other settlement (indefinite leave)
# 27452    Granted     386           Other settlement (indefinite leave)
# 27453    Refused      81           Other settlement (indefinite leave)
# 27454  Withdrawn       9           Other settlement (indefinite leave)
# 27455     Lapsed       0           Other settlement (indefinite leave)
#
# [22017 rows x 6 columns]
